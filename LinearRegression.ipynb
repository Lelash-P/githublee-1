# %% [markdown]
# <a href="https://colab.research.google.com/github/Lelash-P/githublee-1/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
# LINEAR REGRESSION (FIXED)
# ================================
import pandas as pd

# Directly load file from Colab
df = pd.read_csv('/content/homeprices.csv')

print(df.head())

# Preprocessing
df = df.dropna()
df = pd.get_dummies(df)

# Features & Target
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Convert target to numeric
y = pd.to_numeric(y, errors='coerce')

# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Evaluation
from sklearn.metrics import mean_squared_error, r2_score
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# MSE: 41802913.1985723
# R2 Score: nan
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
